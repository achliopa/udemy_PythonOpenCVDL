# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('../DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
fixed_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fixed_img)

# %%
img_gray = cv2.imread('../DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
new_img = cv2.resize(fixed_img,(90,60))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.1
h_ratio = 0.1
new2_img = cv2.resize(fixed_img,(0,0),fixed_img,w_ratio,h_ratio)

# %%
plt.imshow(new2_img)

# %%
fl_img = cv2.flip(fixed_img,-1)

# %%
plt.imshow(fl_img)

# %%
cv2.imwrite('fixed.jpg',fixed_img)
# Out:
# True
